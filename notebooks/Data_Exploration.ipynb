# %% [markdown]
# __Data presented to us has both numerical as well as text based features.__
#
# *Objectives of this notebook.*
#
# * Whether numerical features are any significant or not.
#
# * Whether we should parse raw content or not ?
# * Is boilerplate code sufficient enough to capture detailed intricacies in the data ?
# * Learn a whole lot new text mining techniques.
# * Learn how to run processes in parallel, which is very important when we want to quickly iterate through our various ideas.

# %% [markdown]
# ** Evaluation Metric - AUC ( Area Under Curve ) **

# %%
# %matplotlib inline

# load libraries
import pandas as pd
import numpy as np
import os
import sys

from urllib.parse import urlparse

import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style('whitegrid')
sns.set_context('poster')

import warnings
warnings.filterwarnings('ignore')

# set seed
np.random.seed(1)

basepath = os.path.expanduser('~/Desktop/src/Stumbleupon_classification_challenge/')
sys.path.append(os.path.join(basepath, 'src'))

# %%
# load files
train = pd.read_csv(os.path.join(basepath, 'data/raw/train.tsv'), delimiter='\t')
test = pd.read_csv(os.path.join(basepath, 'data/raw/test.tsv'), delimiter='\t')
sample_sub = pd.read_csv(os.path.join(basepath, 'data/raw/sampleSubmission.csv'))

# %%
train.head(2)
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
#
#    commonlinkratio_3  commonlinkratio_4  ...    is_news  lengthyLinkDomain  \
# 0           0.047059           0.023529  ...          1                  1
# 1           0.213904           0.144385  ...          1                  1
#
#    linkwordscore  news_front_page  non_markup_alphanum_characters  \
# 0             24                0                            5424
# 1             40                0                            4973
#
#    numberOfLinks  numwords_in_url parametrizedLinkRatio  \
# 0            170                8              0.152941
# 1            187                9              0.181818
#
#    spelling_errors_ratio  label
# 0               0.079130      0
# 1               0.125448      1
#
# [2 rows x 27 columns]

# %%
test.head(2)
# Out:
#                                                  url  urlid  \
# 0  http://www.lynnskitchenadventures.com/2009/04/...   5865
# 1            http://lolpics.se/18552-stun-grenade-ar    782
#
#                                          boilerplate  alchemy_category  \
# 0  {"title":"Homemade Enchilada Sauce Lynn s Kitc...        recreation
# 1  {"title":"lolpics Stun grenade ar ","body":" f...  culture_politics
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.443906     2.558140           0.389706           0.257353
# 1               0.135844     3.771429           0.461538           0.205128
#
#    commonlinkratio_3  commonlinkratio_4          ...            image_ratio  \
# 0           0.044118           0.022059          ...               0.199438
# 1           0.051282           0.000000          ...               0.080000
#
#    is_news  lengthyLinkDomain  linkwordscore  news_front_page  \
# 0        1                  1             15                0
# 1        ?                  1             62                0
#
#    non_markup_alphanum_characters  numberOfLinks numwords_in_url  \
# 0                            5643            136               3
# 1                             382             39               2
#
#    parametrizedLinkRatio  spelling_errors_ratio
# 0               0.242647               0.080597
# 1               0.128205               0.176471
#
# [2 rows x 26 columns]

# %%
sample_sub.head()
# Out:
#    urlid  label
# 0   5865      0
# 1    782      0
# 2   6962      0
# 3   7640      0
# 4   3589      0

# %%
# remove urlid from the train and test and store them in separate variable
def fetch_urlid(data):
    return data['urlid']

def delete_urlid(data):
    del data['urlid']

train_urlid = fetch_urlid(train)
test_urlid = fetch_urlid(test)

delete_urlid(train)
delete_urlid(test)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
train.columns
# Out:
# Index(['url', 'boilerplate', 'alchemy_category', 'alchemy_category_score',
#        'avglinksize', 'commonlinkratio_1', 'commonlinkratio_2',
#        'commonlinkratio_3', 'commonlinkratio_4', 'compression_ratio',
#        'embed_ratio', 'framebased', 'frameTagRatio', 'hasDomainLink',
#        'html_ratio', 'image_ratio', 'is_news', 'lengthyLinkDomain',
#        'linkwordscore', 'news_front_page', 'non_markup_alphanum_characters',
#        'numberOfLinks', 'numwords_in_url', 'parametrizedLinkRatio',
#        'spelling_errors_ratio', 'label'],
#       dtype='object')

# %% [markdown]
# ** Let's see the url variable. **

# %% [markdown]
# ** Lets create a variable which counts the depth in the url. **
#
# e.g. www.guardian.co.uk/a has depth 1, whereas www.guardian.co.uk/a/b has depth 2

# %%
def url_depth(url):
    """
    Takes in a url and calculates depth
    e.g. www.guardian.co.uk/a has depth 1, whereas www.guardian.co.uk/a/b has depth 2
    
    url - url of the webpage
    """
    
    parsed_url = urlparse(url)
    path = parsed_url.path
    
    return len(path.split('/')) - 1

url_depths = train.url.map(url_depth)
assert len(url_depths) == len(train.label)

# %%
feature_df = pd.DataFrame({'url_depths': url_depths, 'label': train.label})

# %% [markdown]
# ** Validate the hypothesis that this feature is actually indicative or not. **
#
# 1. Split the dataset into training and test set
# 2. Set up a cross validation scheme.
# 3. Record the final performance on the test set.

# %%
pd.crosstab(feature_df.url_depths, feature_df.label)
# Out:
# label         0     1
# url_depths
# 1           739   590
# 2           935   852
# 3           714  1033
# 4           544   651
# 5           414   479
# 6           139   132
# 7            66    42
# 8             9     8
# 9            39     9

# %%
urlparse(train.url.iloc[17]).path
# Out:
# '/fashion/gallery/2012/jul/08/gentlemen-compete-chap-olympiad-in-pictures'

# %%
train[['url', 'label']]
# Out:
#                                                     url  label
# 0     http://www.bloomberg.com/news/2010-12-23/ibm-p...      0
# 1     http://www.popsci.com/technology/article/2012-...      1
# 2     http://www.menshealth.com/health/flu-fighting-...      1
# 3     http://www.dumblittleman.com/2007/12/10-foolpr...      1
# 4     http://bleacherreport.com/articles/1205138-the...      0
# 5     http://www.conveniencemedical.com/genital-herp...      0
# 6     http://gofashionlane.blogspot.tw/2012/06/ameri...      1
# 7     http://www.insidershealth.com/article/racing_f...      0
# 8     http://www.valetmag.com/the-handbook/features/...      1
# 9     http://www.howsweeteats.com/2010/03/24/cookies...      1
# 10                              http://www.reuters.com/      0
# 11    http://www.midwestsportsfans.com/2010/12/photo...      0
# 12    http://www.ivillage.com/our-dirty-mouths/4-b-1...      1
# 13    http://www.thedailygreen.com/print-this/health...      1
# 14    http://www.phillyburbs.com/blogs/type-a-kitche...      0
# 15    http://sportsillustrated.cnn.com/2012_swimsuit...      0
# 16    http://theawesomer.com/liquid-mountaineering/3...      0
# 17    http://www.guardian.co.uk/fashion/gallery/2012...      0
# 18    http://sugarcrafter.net/2011/06/06/grilled-pea...      1
# 19    http://www.ivillage.com/bathroom-degrunge-your...      1
# 20    http://www.tmz.com/2012/12/20/olympic-soccer-a...      0
# 21    http://www.bbc.co.uk/food/recipes/blueberry_an...      1
# 22           http://www.quitcounter.com/quitsmoking.php      0
# 23    http://www.monicel.info/2008/08/03/original-te...      1
# 24    http://blogs.babble.com/family-kitchen/2011/04...      1
# 25    http://www.midwestsportsfans.com/2010/10/early...      0
# 26                         http://breakingnewsblog.com/      0
# 27    http://www.naffziger.net/blog/2008/07/05/the-a...      0
# 28    http://humor.cool-been.com/wp/supermodels-show...      1
# 29    http://sportsillustrated.cnn.com/2011_swimsuit...      1
# ...                                                 ...    ...
# 7365                  http://cheezburger.com/6631333376      1
# 7366      http://www.newsweek.com/id/43884/output/print      0
# 7367  http://ca.askmen.com/sports/foodcourt_250/253_...      1
# 7368  http://www.cafejohnsonia.com/2011/08/sourdough...      1
# 7369   http://noblepig.com/2009/05/10/just-amazing.aspx      1
# 7370   http://www.nastygal.com/clothes/fancy-knot-dress      0
# 7371  http://betterinbulk.net/2012/10/perfect-pumpki...      1
# 7372  http://dornob.com/get-the-lead-out-cartridge-f...      0
# 7373                            http://blog.khymos.org/      0
# 7374  http://www.guardian.co.uk/fashion/gallery/2012...      0
# 7375                   http://www.whatmegansmaking.com/      0
# 7376                http://www.chinesefood-recipes.com/      1
# 7377  http://www.forbes.com/sites/greatspeculations/...      0
# 7378  http://www.foodnetwork.com/recipes-and-cooking...      1
# 7379  http://www.savoringthethyme.com/2011/08/toaste...      1
# 7380  http://m.ivillage.com/wicked-good-chocolate-pe...      0
# 7381                       http://www.caravanstyle.com/      0
# 7382  http://www.allthingscupcake.com/2007/12/05/mou...      1
# 7383                  http://randomrr.com/80s-kids.html      1
# 7384  http://iammommy.typepad.com/i_am_baker/2011/02...      1
# 7385  http://shopmarkethq.com/collections/brands-min...      0
# 7386  http://slice.seriouseats.com/archives/2010/06/...      1
# 7387  http://achicdirection.com/2012/01/23/vintage-f...      1
# 7388  http://www.villagevoice.com/bestof/2009/award/...      0
# 7389  http://www.worth1000.com/emailthis.asp?entry=5...      0
# 7390  http://techcrunch.com/2010/09/08/kno-raises-46...      0
# 7391  http://www.uncoached.com/category/why-i-miss-c...      0
# 7392  http://eatthis.menshealth.com/slide/sweet-pota...      1
# 7393                          http://naturallyella.com/      1
# 7394  http://sportsillustrated.cnn.com/2011_swimsuit...      0
#
# [7395 rows x 2 columns]
